# %%
import pandas as pd
import numpy as np
import os
import glob
import muDIC as dic
# Out:
# No module named 'noise'
# The package: noise, is not installed. Perlin speckle is not available

# %%
example_path = 'C:\\Users\\dmchacon\\Documents\\OAK-D Videos\\2_8\\1-14442C107152C0D200\\left'
image_stack = dic.image_stack_from_folder(example_path,file_type=".png")
mesher = dic.Mesher()
# Out:
# root:INFO:Found 1533 images in folder

# %%
mesh = mesher.mesh(image_stack)
# Out:
# muDIC.mesh.meshUtilities:INFO:Using Q4 elements
# muDIC.mesh.meshUtilities:INFO:Element contains 25.0 X 25.0 pixels and is divided in 4 X 4
# Use arraow keys to move mesh, W and X to change refinement in  Y-directions, A and D to change refinement in X-direction
